# %%
import pandas as pd
import numpy as np

# %%
census = pd.read_csv('census.csv', index = 'State')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-676dfe80bb2b> in <module>()
# ----> 1 census = pd.read_csv('census.csv', index = 'State')
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
census
# Out:
#                                                     City  \
# 0                                          New York city
# 1                                       Los Angeles city
# 2                                           Chicago city
# 3                                           Houston city
# 4                                           Phoenix city
# 5                                      Philadelphia city
# 6                                       San Antonio city
# 7                                         San Diego city
# 8                                            Dallas city
# 9                                          San Jose city
# 10                                           Austin city
# 11                                     Jacksonville city
# 12                                    San Francisco city
# 13                                         Columbus city
# 14                           Indianapolis city (balance)
# ...
